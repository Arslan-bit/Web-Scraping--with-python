# %% [markdown]
# # Import

# %%
import requests
from  bs4 import BeautifulSoup
import numpy as np
import string
from urllib.request import Request, urlopen
import re
import os
from urllib.parse import urljoin

# %% [markdown]
# # URLs

# %%
# url = "https://stackoverflow.com/questions/30042334/attribute-error-list-object-has-no-attribute-split"
# url = "https://www.geeksforgeeks.org/create-a-directory-in-python/"
# url='https://en.wikipedia.org/wiki/Imran_Khan'
url='https://stackoverflow.com/questions/3711856/how-to-remove-empty-lines-with-or-without-whitespace-in-python'

# %% [markdown]
# # Get The Heading

# %%
r = requests.get(url)
htmlcontents  = r.content
# print(htmlcontents)
soop = BeautifulSoup(htmlcontents,'html.parser')
# print(soop.prettify())

paragraph = soop.find_all('p')
# print(paragraph)

heading = soop.find('title')
heaad = heading.text

# %%
print((heaad))
# Out:
# string - How to remove empty lines with or without whitespace in Python - Stack Overflow

# %% [markdown]
# # Analyse the Heading

# %%
# a_string = '!hi. wh?at is the weat[h]er lik?e.'
a_string = heaad
new_string = a_string.translate(str.maketrans('', '', string.punctuation))

print(new_string)
# Out:
# string  How to remove empty lines with or without whitespace in Python  Stack Overflow

# %% [markdown]
# # Create Main Directory

# %%
# Directory
directory = new_string
  
# Parent Directory path
parent_dir = "C:/"
  
# Path join
path = os.path.join(parent_dir, directory)
  
os.mkdir(path)
print("Directory '% s' created" % directory)
print(path)
# Out:
# Directory 'string  How to remove empty lines with or without whitespace in Python  Stack Overflow' created
# C:/string  How to remove empty lines with or without whitespace in Python  Stack Overflow

# %% [markdown]
# # Make List Sub Directory

# %%
sub_add_dir = parent_dir + directory +"/"
# print(sub_add_dir)
list = ["html","css","java"]

# %% [markdown]
# # Create Sub Directory in Main Directory

# %%
n=0
while n <len(list):
    sub_directory =list[n] 

    # Path join
    spath = os.path.join(sub_add_dir, sub_directory)

    os.mkdir(spath)
    
    print("Directory '% s' created" % sub_directory)
    
    n=n+1
# Out:
# Directory 'html' created
# Directory 'css' created
# Directory 'java' created

# %%
# print(path)

# %%
N_folder = os.listdir(path)
print(N_folder)
n = len(N_folder)
print(n)
# Out:
# ['css', 'html', 'java']
# 3

# %% [markdown]
# # Create .txt file in the sub Directorys

# %%
n=0
while n<len(N_folder):
    
    file = open(path + '/' + N_folder[n] + '/' + N_folder[n] + '.txt','w')
    file.close

    print((path + '/' + N_folder[n] + '/' + N_folder[n] + '.txt'))
    
    n=n+1
# Out:
# C:/string  How to remove empty lines with or without whitespace in Python  Stack Overflow/css/css.txt
# C:/string  How to remove empty lines with or without whitespace in Python  Stack Overflow/html/html.txt
# C:/string  How to remove empty lines with or without whitespace in Python  Stack Overflow/java/java.txt

# %% [markdown]
# # Extract & split the HTML and save in html.txt file

# %%
# HTML
req = Request(url)
html_page = urlopen(req)

soup = BeautifulSoup(html_page, "html.parser")

html_text = soup.get_text()

# %%
lines = html_text.split("\n")

non_empty_lines = [line for line in lines if line.strip() != ""]


html_text = ""

for line in non_empty_lines:

      html_text += line + "\n"

# print(html_text)
print( html_text)

f = open(path + '/' + N_folder[1] + '/' + N_folder[1] + '.txt','w',encoding='utf-8')         # Creating html_text.txt File

for line in html_text:
	f.write(line)

f.close()
# Out:
# string - How to remove empty lines with or without whitespace in Python - Stack Overflow
# Stack Overflow
# About
#                         Products
# For Teams
# Stack Overflow
# Public questions & answers
# Stack Overflow for Teams
# Where developers & technologists share private knowledge with coworkers
# Talent
#                                 Build your employer brand
# Advertising
# Reach developers & technologists worldwide
# About the company
# Loading…
# current community
#             Stack Overflow
# help
# chat
#             Meta Stack Overflow
# your communities
# Sign up or log in to customize your list.
# more stack exchange communities
# company blog
# Log in
# Sign up
#                     Home
# Public
#  Questions
#                     Tags
#                     Users
#                     Companies
# Collectives
#  Explore Collectives
# Teams
# Stack Overflow for Teams
#         – Start collaborating and sharing organizational knowledge.
# Create a free Team
# Why Teams?
# Teams
#                             Create free Team
# Collectives™ on Stack Overflow
# Find centralized, trusted content and collaborate around the technologies you use most.
#                     Learn more about Collectives
# Teams
# Q&A for work
# Connect and share knowledge within a single location that is structured and easy to search.
#                     Learn more about Teams
# How to remove empty lines with or without whitespace in Python
#         Ask Question
# Asked
# 12 years, 1 month ago
# Modified
# 10 months ago
# Viewed
#                         196k times
#             47
# New! Save questions or answers and organize your favorite content. Learn more.
# I have large string which I split by newlines.
# How can I remove all lines that are empty, (whitespace only)?
# pseudo code:
# for stuff in largestring:
#    remove stuff that is blank
# pythonstring
# Share
# Improve this question
#                     Follow
# edited Nov 3, 2016 at 18:49
# ViFI
# 92511 gold badge1010 silver badges2424 bronze badges
#         asked Sep 14, 2010 at 18:35
#         user428370user428370
# 2
# 3
# For myself, I found the answer here is the best solution
# – Dmitriy
# Oct 5, 2016 at 6:00
# 2
# One liner to remove empty lines (without whitespace) is this .  Question headline could potentially be changed to 'Remove empty lines with whitespace only in python'.
# – ViFI
# Nov 3, 2016 at 6:41
# Add a comment
#  |
#                                         12 Answers
#                                     12
#             Sorted by:
#             Reset to default
#                         Highest score (default)
#                         Trending (recent votes count more)
#                         Date modified (newest first)
#                         Date created (oldest first)
#             66
# Try list comprehension and string.strip():
# >>> mystr = "L1\nL2\n\nL3\nL4\n  \n\nL5"
# >>> mystr.split('\n')
# ['L1', 'L2', '', 'L3', 'L4', '  ', '', 'L5']
# >>> [line for line in mystr.split('\n') if line.strip() != '']
# ['L1', 'L2', 'L3', 'L4', 'L5']
# Share
# Improve this answer
#                     Follow
#         answered Sep 14, 2010 at 18:45
# gimelgimel
# 80.3k1010 gold badges7474 silver badges104104 bronze badges
# 1
# 15
# you can shorten it by omitting the  != ''  simply "if line.strip()"
# – WestCoastProjects
# Jun 17, 2013 at 21:38
# Add a comment
#  |
#             52
# Using regex:
# if re.match(r'^\s*$', line):
#     # line is empty (has only the following: \t\n\r and whitespace)
# Using regex + filter():
# filtered = filter(lambda x: not re.match(r'^\s*$', x), original)
# As seen on codepad.
# Share
# Improve this answer
#                     Follow
# edited Sep 14, 2010 at 18:48
#         answered Sep 14, 2010 at 18:38
# NullUserExceptionNullUserException
# 82.2k2727 gold badges206206 silver badges231231 bronze badges
# 3
# 2
# Thanks for all the results, however, this solution was exactly what I had been looking for! Thanks a lot
# – user428370
# Sep 14, 2010 at 19:01
# 5
# gimel's solution, with re-joining the text afterwards, gives a far better performance. I compared the two solutions on a small text (10 lines if which 3 were blank). Here are the results: regex: 1000 loops, best of 3: 452 us per loop;  join, split & strip: 100000 loops, best of 3: 5.41 us per loop
# – m01
# May 28, 2013 at 8:48
# Introductory video: Python Tutorial: re Module - How to Write and Match Regular Expressions (Regex) - YouTube
# – Ooker
# Aug 23, 2019 at 13:28
# Add a comment
#  |
#             23
# I also tried regexp and list solutions, and list one is faster.
# Here is my solution (by previous answers):
# text = "\n".join([ll.rstrip() for ll in original_text.splitlines() if ll.strip()])
# Share
# Improve this answer
#                     Follow
#         answered Jul 12, 2013 at 8:24
# RegiszRegisz
# 44188 silver badges1515 bronze badges
# 0
# Add a comment
#  |
#             12
# lines = bigstring.split('\n')
# lines = [line for line in lines if line.strip()]
# Share
# Improve this answer
#                     Follow
# edited Jun 23, 2020 at 13:58
#         answered Sep 14, 2010 at 18:45
# nmichaelsnmichaels
# 48.3k1212 gold badges102102 silver badges133133 bronze badges
# 4
# 1
# That would work for lines = ['Line\n', '\n', 'Line\n'] but the input is 'Line\n\nLine\n' .
# – Walter Nissen
# Sep 14, 2010 at 18:54
# 2
# @Walter: Actually, if you used 'Line\n\nLine\n'.split() like you should have, it would work just fine.
# – nmichaels
# Sep 14, 2010 at 19:42
# 1
# Works for me with bigstring.split('\n')
# – Hritik
# Dec 31, 2018 at 18:18
# This isn't at all what OP asks for.  Try it with "a b c": it returns "a\nb\nc".
# – Clément
# Jun 22, 2020 at 2:58
# Add a comment
#  |
#             7
# Surprised a multiline re.sub has not been suggested (Oh, because you've already split your string... But why?):
# >>> import re
# >>> a = "Foo\n \nBar\nBaz\n\n   Garply\n  \n"
# >>> print a
# Foo
# Bar
# Baz
#         Garply
# >>> print(re.sub(r'\n\s*\n','\n',a,re.MULTILINE))
# Foo
# Bar
# Baz
#         Garply
# >>>
# Share
# Improve this answer
#                     Follow
#         answered May 17, 2018 at 18:45
# mushuweaselmushuweasel
# 60477 silver badges77 bronze badges
# 1
# 1
# On a multiline sub, \s* will match any number of \n and any other whitespace: > >>> import re > >>> a = "foo\n \n\t\n \nbar\n\n \n baz" > >>> print(re.sub(r'\n\s*\n','\n',a,re.MULTILINE)) > foo > bar >   baz  grumble.  I apparently can't figure out markdown in comments.
# – mushuweasel
# Aug 13, 2019 at 21:17
# Add a comment
#  |
#             3
# If you are not willing to try regex (which you should), you can use this:
# s.replace('\n\n','\n')
# Repeat this several times to make sure there is no blank line left. Or chaining the commands:
# s.replace('\n\n','\n').replace('\n\n','\n')
# Just to encourage you to use regex, here are two introductory videos that I find intuitive:
# • Regular Expressions (Regex) Tutorial
# • Python Tutorial: re Module
# Share
# Improve this answer
#                     Follow
# edited Aug 23, 2019 at 13:27
#         answered Sep 1, 2015 at 17:54
# OokerOoker
# 1,39733 gold badges2424 silver badges5050 bronze badges
# 4
# 2
# You may want to use a regular expression, for example. "Repeat several lines to be sure" is not a good idea when you are coding, as you may leave things unsolved or waste time running something more times than needed.
# – Enrico
# Jun 21, 2016 at 4:55
# +1 to regex, but as a lazy hack (or if importing the regex module is too slow) you can chain replace statements:  s.replace('\n\n','\n').replace('\n\n','\n') Tested on 3.6.
# – evan_b
# Jun 16, 2017 at 5:28
# @evan_b didn't think of chaining commands. Which one will be executed first?
# – Ooker
# Jun 16, 2017 at 15:03
# 1
# Execution order appears to be left to right, but I wasn't able to find that documented anywhere after searching briefly, so it may not be safe to rely on that for order-sensitive replacements.
# – evan_b
# Jun 17, 2017 at 22:53
# Add a comment
#  |
#             2
# you can simply use rstrip:
#     for stuff in largestring:
#         print(stuff.rstrip("\n")
# Share
# Improve this answer
#                     Follow
#         answered Apr 11, 2019 at 10:27
# Rahul PandeyRahul Pandey
# 10322 silver badges44 bronze badges
# Add a comment
#  |
#             1
# I use this solution to delete empty lines and join everything together as one line:
# match_p = re.sub(r'\s{2}', '', my_txt) # my_txt is text above
# Share
# Improve this answer
#                     Follow
# edited Jul 22, 2020 at 6:41
# Cody Gray♦
# 234k5050 gold badges482482 silver badges560560 bronze badges
#         answered Nov 22, 2018 at 13:26
# red fredred fred
# 1111 bronze badge
# Add a comment
#  |
#             0
# My version:
# while '' in all_lines:
#     all_lines.pop(all_lines.index(''))
# Share
# Improve this answer
#                     Follow
#         answered Sep 10, 2015 at 12:49
# RadrenRadren
# 30744 silver badges66 bronze badges
# Add a comment
#  |
#             0
# Use positive lookbehind regex:
# re.sub(r'(?<=\n)\s+', '', s, re.MULTILINE)
# When you input:
# foo
# <tab> <tab>
# bar
# The output will be:
# foo
# bar
# Share
# Improve this answer
#                     Follow
#         answered Jul 7, 2021 at 10:06
# KxrrKxrr
# 49455 silver badges1313 bronze badges
# 1
# This doesn't work on first line of the file :(
# – Martin
# Jun 20 at 10:18
# Add a comment
#  |
#             0
# str_whith_space = """
#     example line 1
#     example line 2
#     example line 3
#     example line 4"""
# new_str = '\n'.join(el.strip() for el in str_whith_space.split('\n') if el.strip())
# print(new_str)
# Output:
# """ <br>
# example line 1 <br>
# example line 2 <br>
# example line 3 <br>
# example line 4 <br>
# """
# Share
# Improve this answer
#                     Follow
# edited Dec 16, 2021 at 22:34
# Patrick
# 1,20655 gold badges1010 silver badges1919 bronze badges
#         answered Dec 16, 2021 at 5:53
# Павел ГоняевПавел Гоняев
# 1111 bronze badge
# Add a comment
#  |
#             -1
# Same as what @NullUserException said, this is how I write it:
# removedWhitespce = re.sub(r'^\s*$', '', line)
# Share
# Improve this answer
#                     Follow
#         answered May 24, 2017 at 19:07
# Reihan_amnReihan_amn
# 2,58522 gold badges1919 silver badges2020 bronze badges
# Add a comment
#  |
#                                     Your Answer
# Thanks for contributing an answer to Stack Overflow!Please be sure to answer the question. Provide details and share your research!But avoid …Asking for help, clarification, or responding to other answers.Making statements based on opinion; back them up with references or personal experience.To learn more, see our tips on writing great answers.
# Draft saved
# Draft discarded
# Sign up or log in
#  Sign up using Google
#  Sign up using Facebook
#  Sign up using Email and Password
# Submit
# Post as a guest
# Name
# Email
# Required, but never shown
# Post as a guest
# Name
# Email
# Required, but never shown
# Post Your Answer
#                                             Discard
#                                                 By clicking “Post Your Answer”, you agree to our terms of service, privacy policy and cookie policy
#                         The Overflow Blog
# How observability-driven development creates elite performers
# The robots are coming… but when? (Ep 496)
#                         Featured on Meta
# Bookmarks have evolved into Saves
# Inbox improvements: marking notifications as read/unread, and a filtered...
# Collectives Update: Recognized Members, Articles, and GitLab
# The [script] tag is being burninated
# Linked
# 1
# python: how to delete blank lines?
# 81
# What's a quick one-liner to remove empty lines from a python string?
# 2
# python tesseract results giving unwanted extra line gaps between sentences
# 2
# How to remove blank lines in text file python?
# -1
# How do I remove the empty line from this file?
# 0
# Remove <br> from element being extracted
# 1
# How to use text in TextEdit and apply changes to it? Like my code see it and say me what can I do in -btn_func- function?
# 0
# Remove all blank lines from a text file in python
# Related
# 3230
# How do I check if a list is empty?
# 6789
# How do I check whether a file exists without exceptions?
# 3302
# Case insensitive 'Contains(string)'
# 1355
# Trim string in JavaScript
# 3416
# How do I sort a dictionary by value?
# 5278
# How do I replace all occurrences of a string in JavaScript?
# 1874
# How do I split a string in Java?
# 1140
# Remove all whitespace in a string
# 2112
# Why is reading lines from stdin much slower in C++ than Python?
# 1822
# How do I split the definition of a long string over multiple lines?
#             Hot Network Questions
#                     Conflicting meanings for "犬も歩けば" expression?
#                     How does a fund follow an index?
#                     Can we use the verb "milk" with humans, for example, "The mom milked her breast / herself by machine"?
#                     Windows too small for frame?
#                     Would human intelligence evolve if humans had access to infinite food?
#                     Font size change when I change the font?
#                     Why is a Calculus III student more likely to answer this question?
#                     Is it possible to create a 'see through' mirror object
#                     Ambiguity in determining the owner of a genitive personal pronoun
#                     halt not emitting any logging/shutdown info, how to improve robust reporting or visual logging?
#                     Verb ellipsis (or not)
#                     Are the inequalities from Bell's Theorem ever actually satisfied?
#                     Why don't countries welcome high energy prices to fight climate change?
#                     fdisk reports partitions are misaligned even when they don't appear to be
#                     Flutter apply method to static variable
#                     Is code written inline faster than using function calls?
#                     How can I write the next step exactly below the previous step in the equation without repeating the L.H.S. of the equation?
#                     Understanding vector re-projection process/steps
#                     Implement the flip-floperator
#                     Miller's manager was not amused
#                     How could Mars' atmosphere be shed by solar winds, when Venus has a thick atmosphere despite no magnetic field?
#                     Upper bound on the trace over POVM element and density matrix
#                     Best approach to count Seven Four Signature (7/4)?
#                     How to prove that if a series converges, then the sequence of it's terms multiplies by the inverses of their positions converges
#             more hot questions
#             Question feed
#                 Subscribe to RSS
#                         Question feed
#                         To subscribe to this RSS feed, copy and paste this URL into your RSS reader.
# lang-py
# Stack Overflow
# Questions
# Help
# Products
# Teams
# Advertising
# Collectives
# Talent
# Company
# About
# Press
# Work Here
# Legal
# Privacy Policy
# Terms of Service
# Contact Us
# Cookie Settings
# Cookie Policy
# Stack Exchange Network
#                                     Technology
#                                     Culture & recreation
#                                     Life & arts
#                                     Science
#                                     Professional
#                                     Business
#                                     API
#                                     Data
# Blog
# Facebook
# Twitter
# LinkedIn
# Instagram
# Site design / logo © 2022 Stack Exchange Inc; user contributions licensed under CC BY-SA.                    rev 2022.10.14.26767
#                         Your privacy
#                         By clicking “Accept all cookies”, you agree Stack Exchange can store cookies on your device and disclose information in accordance with our Cookie Policy.
#                             Accept all cookies
#                             Customize settings

# %%
# html_text1 = html_text.translate(str.maketrans('', '', string.punctuation))
# print(html_text1)

# %% [markdown]
#  # Extract the Java and save in java.txt file

# %%
# Java Urls
script_files = []

for script in soup.find_all("script"):
    if script.attrs.get("src"):
        # if the tag has the attribute 'src'
        script_url = urljoin(url, script.attrs.get("src"))
        script_files.append(script_url)
        


f = open(path + '/' + N_folder[2] + '/' + N_folder[2] + '.txt','w',encoding='utf-8')         # Creating html_text.txt File

for line in script_files:
	f.write(line)

f.close()

print(script_files)
# Out:
# ['https://ajax.googleapis.com/ajax/libs/jquery/1.12.4/jquery.min.js', 'https://cdn.sstatic.net/Js/third-party/npm/@stackoverflow/stacks/dist/js/stacks.min.js?v=facbc6b2f3b6', 'https://cdn.sstatic.net/Js/stub.en.js?v=0e3ada576039', 'https://www.googletagmanager.com/gtag/js?id=G-WCZ03SZFCQ']

# %% [markdown]
# #  Extract the CSS and save in css.txt file

# %%
# CSS Urls
css_files = []

for css in soup.find_all("link"):
    if css.attrs.get("href"):
        # if the link tag has the 'href' attribute
        css_url = urljoin(url, css.attrs.get("href"))
        css_files.append(css_url)
        


f = open(path + '/' + N_folder[0] + '/' + N_folder[0] + '.txt','w',encoding='utf-8')         # Creating html_text.txt File

for line in css_files:
	f.write(line)

f.close()
print(css_files)
# Out:
# ['https://cdn.sstatic.net/Sites/stackoverflow/Img/favicon.ico?v=ec617d715196', 'https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a', 'https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a', 'https://stackoverflow.com/opensearch.xml', 'https://stackoverflow.com/questions/3711856/how-to-remove-empty-lines-with-or-without-whitespace-in-python', 'https://cdn.sstatic.net/Shared/stacks.css?v=5ad0f45f4799', 'https://cdn.sstatic.net/Sites/stackoverflow/primary.css?v=0cc30ee01b86', 'https://stackoverflow.com/feeds/question/3711856', 'https://cdn.sstatic.net/Shared/Channels/channels.css?v=d098999fc478', 'https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a']
